# %%
import pandas as pd

# %%
df = pd.read_csv("nyc_taxi_data.csv")

# %%
df
# Out:
#         End_Lat    End_Lon  Fare_Amt  Passenger_Count Payment_Type  Rate_Code  \
# 0     40.742963 -73.980072      45.0                1       Credit        NaN
# 1     40.740187 -74.005698       6.5                1       Credit        NaN
# 2     40.718043 -74.004745      12.5                5       Credit        NaN
# 3     40.739637 -73.985233       4.9                1         CASH        NaN
# 4     40.730032 -73.852693      25.7                1         CASH        NaN
# ...         ...        ...       ...              ...          ...        ...
# 9995  40.783522 -73.970690       5.7                1         CASH        NaN
# 9996  40.777200 -73.964197       4.1                1         CASH        NaN
# 9997  40.780172 -73.957617       6.1                1         CASH        NaN
# 9998  40.777342 -73.957242       5.7                1         CASH        NaN
# 9999  40.757122 -73.986293       6.5                1       Credit        NaN
#
# ...

# %%
min(df.Trip_Dropoff_DateTime)
# Out:
# '2009-06-01 11:48:00'

# %%
max(df.Trip_Dropoff_DateTime)
# Out:
# '2009-07-01 00:03:00'

# %%
(df.Payment_Type == "Credit").sum()/10000
# Out:
# np.float64(0.2666)

# %%
df.Tip_Amt.sum()
# Out:
# np.float64(6063.41)
